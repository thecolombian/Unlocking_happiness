# %%
import pandas as pd

# %%
health_remote_df = pd.read_csv('health-remote-work-v3.csv')
health_remote_df
# Out:
#       Employee_ID  Age      Gender           Job_Role    Industry  \
# 0         EMP0001   32  Non-binary                 HR  Healthcare
# 1         EMP0002   40      Female     Data Scientist          IT
# 2         EMP0003   59  Non-binary  Software Engineer   Education
# 3         EMP0004   27        Male  Software Engineer     Finance
# 4         EMP0005   49        Male              Sales  Consulting
# ...           ...  ...         ...                ...         ...
# 14995    EMP14996   32        Male              Sales  Consulting
# 14996    EMP14997   39      Female              Sales  Healthcare
# 14997    EMP14998   42      Female              Sales  Healthcare
# 14998    EMP14999   27      Female              Sales  Healthcare
# 14999    EMP15000   29        Male                 HR          IT
#
#        Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                       13        Remote                     43
# ...

# %%
health_remote_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        15000 non-null  object
#  1   Age                                15000 non-null  int64
#  2   Gender                             15000 non-null  object
#  3   Job_Role                           15000 non-null  object
#  4   Industry                           15000 non-null  object
#  5   Years_of_Experience                15000 non-null  int64
#  6   Work_Location                      15000 non-null  object
#  7   Hours_Worked_Per_Week              15000 non-null  int64
#  8   Number_of_Virtual_Meetings         15000 non-null  int64
#  9   Work_Life_Balance_Rating           15000 non-null  int64
#  10  Stress_Level                       15000 non-null  object
# ...

# %%
health_remote_df['Job_Role'].nunique()
# Out:
# 7

# %%
health_remote_df['Industry'].nunique()
# Out:
# 7

# %%
unique_items_list = health_remote_df['Job_Role'].unique().tolist()
unique_items_list
# Out:
# ['HR',
#  'Data Scientist',
#  'Software Engineer',
#  'Sales',
#  'Marketing',
#  'Designer',
#  'Project Manager']

# %%
unique_items_list = health_remote_df['Industry'].unique().tolist()
unique_items_list
# Out:
# ['Healthcare',
#  'IT',
#  'Education',
#  'Finance',
#  'Consulting',
#  'Manufacturing',
#  'Retail']

# %%
health_remote_df['Region'].value_counts()
# Out:
# Region
# Oceania          2601
# Africa           2580
# Europe           2520
# Asia             2487
# South America    2481
# North America    2331
# Name: count, dtype: int64
