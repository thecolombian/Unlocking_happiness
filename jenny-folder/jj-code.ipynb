# %%
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
# # read in dataset into a df
# child_mortality_df = pd.read_csv('Resources/child-mortality-gdp-per-capita-2011-2022.csv')
# child_mortality_df

# %%
# child_mortality_df.drop(columns=['900793-annotations', 'Continent'], inplace=True)
# child_mortality_df

# %%
happiness_cantril_df = pd.read_csv('SOURCES/New_data_sources/happiness-cantril-ladder-Self-reported life satisfaction 2011 to 2023.csv')
happiness_cantril_df
# Out:
#            Entity Code  Year  Cantril ladder score
# 0     Afghanistan  AFG  2011               4.25835
# 1     Afghanistan  AFG  2014               3.57500
# 2     Afghanistan  AFG  2015               3.36000
# 3     Afghanistan  AFG  2016               3.79400
# 4     Afghanistan  AFG  2017               3.63150
# ...           ...  ...   ...                   ...
# 1782     Zimbabwe  ZWE  2019               3.29920
# 1783     Zimbabwe  ZWE  2020               3.14480
# 1784     Zimbabwe  ZWE  2021               2.99510
# 1785     Zimbabwe  ZWE  2022               3.20350
# 1786     Zimbabwe  ZWE  2023               3.34110
#
# [1787 rows x 4 columns]

# %%
# life_expectancy_df = pd.read_csv('Resources/life-expectancy-vs-healthcare-expenditure-2000-2021.csv')
# life_expectancy_df

# %%
# maternal_mortality_df = pd.read_csv('Resources/Maternal mortality ratio1751 to 2020.csv')
# maternal_mortality_df

# %%
# real_gdp_df = pd.read_csv('Resources/real-gdp-growth-worldwide.csv')
# real_gdp_df

# %%
tb_burden_df = pd.read_csv('SOURCES/TB_Burden_Country.csv')
tb_burden_df
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 0                  Afghanistan                                     AF
# 1                  Afghanistan                                     AF
# 2                  Afghanistan                                     AF
# 3                  Afghanistan                                     AF
# 4                  Afghanistan                                     AF
# ...                        ...                                    ...
# 5115                  Zimbabwe                                     ZW
# 5116                  Zimbabwe                                     ZW
# 5117                  Zimbabwe                                     ZW
# 5118                  Zimbabwe                                     ZW
# 5119                  Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# ...

# %%
# tb_burden_df.columns

# %%
tb_burden_df.rename(columns={'Country or territory name': 'Entity'}, inplace=True)
tb_burden_df
# Out:
#            Entity ISO 2-character country/territory code  \
# 0     Afghanistan                                     AF
# 1     Afghanistan                                     AF
# 2     Afghanistan                                     AF
# 3     Afghanistan                                     AF
# 4     Afghanistan                                     AF
# ...           ...                                    ...
# 5115     Zimbabwe                                     ZW
# 5116     Zimbabwe                                     ZW
# 5117     Zimbabwe                                     ZW
# 5118     Zimbabwe                                     ZW
# 5119     Zimbabwe                                     ZW
#
#      ISO 3-character country/territory code  \
# 0                                       AFG
# 1                                       AFG
# 2                                       AFG
# 3                                       AFG
# 4                                       AFG
# ...

# %%
merged_df = pd.merge(happiness_cantril_df, tb_burden_df, how='inner', on=['Entity', 'Year'] )
merged_df
# Out:
#           Entity Code  Year  Cantril ladder score  \
# 0    Afghanistan  AFG  2011              4.258350
# 1        Albania  ALB  2011              5.133704
# 2        Algeria  DZA  2011              5.367827
# 3         Angola  AGO  2011              4.178380
# 4      Argentina  ARG  2011              6.242357
# ..           ...  ...   ...                   ...
# 130      Uruguay  URY  2011              5.898252
# 131   Uzbekistan  UZB  2011              5.224832
# 132        Yemen  YEM  2011              4.453632
# 133       Zambia  ZMB  2011              4.704553
# 134     Zimbabwe  ZWE  2011              3.978434
#
#     ISO 2-character country/territory code  \
# 0                                       AF
# 1                                       AL
# 2                                       DZ
# 3                                       AO
# 4                                       AR
# ..                                     ...
# 130                                     UY
# ...
